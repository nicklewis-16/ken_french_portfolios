# %%
import pandas as pd

# Replace 'path/to/your/file.parquet' with the actual path to your Parquet file
parquet_file_path = '/Users/zakmehdi/Desktop/University of Chicago/Winter 2024/Data Science Tools for Finance/ken_french_portfolios-1/data/pulled/merged_CRSP_Compustat_data.parquet'

# Read the Parquet file
df = pd.read_parquet(parquet_file_path)

sorted_df = df.sort_values(by='date')
sorted_df.tail(50)
# Out:
#          permno  permco       date    mthret   mthretx     shrout     mthprc  \
# 4078811   93436   53453 2014-06-30  0.155412  0.155412   124588.0  240.06000
# 4078797   93436   53453 2013-04-30  0.424914  0.424914   115553.0   53.99000
# 4078812   93436   53453 2014-07-31 -0.069816 -0.069816   124630.0  223.30000
# 4078814   93436   53453 2014-09-30 -0.100185 -0.100185   125366.0  242.67999
# 4078815   93436   53453 2014-10-31 -0.004038 -0.004038   125382.0  241.70000
# 4078816   93436   53453 2014-11-28  0.011667  0.011667   125382.0  244.52000
# 4078817   93436   53453 2014-12-31 -0.090422 -0.090422   125688.0  222.41000
# 4078818   93436   53453 2015-01-30 -0.084574 -0.084574   125763.0  203.60001
# 4078819   93436   53453 2018-11-30  0.039013  0.039013   171733.0  350.48001
# 4078820   93436   53453 2018-12-31 -0.050445 -0.050445   172602.0  332.79999
# 4078821   93436   53453 2019-01-31 -0.077464 -0.077464   172602.0  307.01999
# ...

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Total number of elements:", df.size)
# Out:
# Number of rows: 4389833
# Number of columns: 8
# Total number of elements: 35118664
